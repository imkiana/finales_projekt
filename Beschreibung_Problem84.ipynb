# %% [markdown]
# # Problem 84: Monopolywahrscheinlichkeiten
# Es wird ein Monopolyspiel mit einem [n > 0] seitigen Würfel simuliert.
# <br>
# Dabei werden Ereignis- und Gemeinschaftskarten beachtet, <br>
# aber keine Pasche, "ab in Gefängnis" oder die Funktion des Gefängnis.

# %% [markdown]
# dice_dn = Seiten und maximale Augenzahl des Würfels.
# <br><br>
# n = Anzahl der Iterationen.
# <br><br>
# plotten = True/False ob die Funktion geplottet werden soll.

# %% [raw]
# Objekt = Monopoly(dice_dn)
# Objekt.fun(n, plotten)

# %% [markdown]
# ![P84.png](attachment:8f9bd07a-f873-4b06-b3d7-884a9873478a.png)
