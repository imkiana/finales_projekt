# %% [markdown]
# # Datenanalyse Indien
# Du kannst dir hiermit für 30 verschiedene Städte <br>
# ein Mosaikplot zu GDP der Stadt sowie <br>
# 7 verschieden Lineplots über 6 Jahre zu den 30 Städte anschauen. <br><br>
# X = erste Stadt im Plot [0<X<30] <br><br>
# N = letzte Stadt im Plot [0<N<30]<br><br>
# plotNummer = Nummer des Plots für plotDevelopment [1-7]

# %%
from meinPaket.Datenanalyse_Indien import Datenanalyse
Objekt = Datenanalyse(X=1,N=4)
Objekt.plotSectors()
Objekt.plotDevelopment()
