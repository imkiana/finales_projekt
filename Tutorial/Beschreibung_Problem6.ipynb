# %% [markdown]
# # Problem 6: Differenzen
# Für eine Beliebige Zahl [n > 0] wird bis zu n Zahl die Differenz zwischen (n+n-1+n-2...n>=0)² und n²+(n-1)²+(n-2)²...n>=0 berechnet.

# %% [markdown]
# n = Zahl bis zu welcher die Funktion läuft.
# <br><br>
# plotten = True/False ob die Funktion geplottet werden soll.

# %% [raw]
# >f(n=5, plotten)
#
# Für n=1 die Differenz ist 0
# Für n=2 die Differenz ist 4
# Für n=3 die Differenz ist 22
# Für n=4 die Differenz ist 70
# Für n=5 die Differenz ist 170

# %% [markdown]
# ![P6.png](attachment:2a2f1afa-e42e-4ee6-9856-d750ab258f19.png)
