# %% [markdown]
# # Problem 2: gerade Fibonacci Zahlen
# Für eine beliebige Zahl [n > 0] wird bis zu dieser Zahl jede gerade Fibonacci Zahl gezählt.

# %% [markdown]
# maximal = Zahl bis zu der die geraden Fibonacci Zahlen gezählt werden sollen.
# <br><br>
# startzahl = Die n-te Fibonacci Zahl von der die Funktion starten soll. z.B.: startzahl = 3 wäre 13.
# <br><br>
# plotten = True/False ob die Funktion geplottet werden soll.

# %%
from meinPaket.Problem2 import Fibonacci
Objekt = Fibonacci(maximal=4_000_000, startzahl=1)
Objekt.fun(plotten=True)
# Out:
# Insgesamt gab es 11 gerade Zahlen, bis zur Zahl 3524578.
